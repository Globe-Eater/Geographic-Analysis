# %%
import pandas as pd
from pandas.plotting import scatter_matrix

# %%
state = pd.read_spss('/Users/kellenbullock/Desktop/Geographic Analysis II/Data/5303_EX_A.sav')
Counties = state.query("Scale == 'Counties'")
df = Counties[['Pct_Black', 'Pct_Two_Plus', 'Pct_SNAP', 'Pct_FIRE_I', 'Pct_Poverty', 'Pct_Unemp', 'Med_HomeValue', 'Pct_White', 'Pct_BlueCollar_O', 'Pct_Hispanic']]

# %%
matrix = scatter_matrix(df, figsize=(12,12), alpha=0.5)
